# %% [markdown]
# <a href="https://colab.research.google.com/github/TurkuNLP/ATP_kurssi/blob/master/2024_Notebook_10_answers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Exercise 1**
#
# Practise using for loops.
#
#
#
# 1.   Print all file names in a folder using for loop.
#
#
#
# ```
# for f in * ; do echo $f ; done #if you are in the folder
# ```
#
# ```
# for f in folder/* ; do echo $f ; done #if you run the for loop on files within a specific folder
# ```
#
# 2.   Print the file names and word count of each file in a folder.
#
#
# ```
# for f in * ; do echo $f ; cat $f | wc -w ; done
# ```
#
#
# 3.   Grep and print all perl scripts in your .sh files in a folder. Print also the .sh file names.
#
#
#
# ```
# for f in *.sh ; do echo $f ; cat $f | egrep "perl" ; done
# ```
#
#
#
# **Exercise 2**
#
# More for loops.
#
# 1.   Run one of your scripts from Notebook9 on two similar files (meaning that the script works equally well on both files) in your folder using a for loop. Print the names and the output in one file.
#
# ```
# for f in real* ; do echo $f ; cat $f | ./mostfrequenthashtag.sh ; done > output_mostfreqhashtags.txt
# ```
#
# 2.   What's the difference if you execute the for loop with `do echo $f` or without it?
#
#
# *   With: the file names are printed in the output file
#
#
# ```
# for f in real* ; do echo $f ; cat $f | ./mostfrequenthashtag.sh ; done > output_mostfreqhashtags.txt
# ```
#
#
# *   Without: only the output is printed in the output file, not the file names
#
#
# ```
# for f in real* ; do cat $f | ./mostfrequenthashtag.sh ; done > output_mostfreqhashtags_nofilename.txt
# ```
#
#
# 3.   Copy the files cricket.csv and icehockey.csv from /home/mavela/data-2022/
#
#
#
# ```
# cp /home/mavela/data-2022/cricket.csv
# ```
# ```
# cp /home/mavela/data-2022/icehockey.csv
# ```
#
#
# 4.   Make a script that counts the words in a file. Exclude numbers and punctuation and other items if needed. Run the script on the cricket and ice hockey files using a for loop and direct the output into separate files.
#
#
#
# ```
# for f in sports/* ; do echo $f ; cat $f | ./word_count.sh > $f-output.txt ; done
# ```
#
# *   Here `do echo $f` prints the file names on the screen and the path to the file (in which folder the file is).
#
#
#
# > `sports/cricket.csv`
#
# > `sports/icehockey.csv`
