# %% [markdown]
# <a href="https://colab.research.google.com/github/TurkuNLP/ATP_kurssi/blob/master/2024_Notebook_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Topics for today:
#
# *   Connecting to a server
# *   Directory structure on the server
# *   Creating folders and files and browsing them
# *   Copying, renaming, moving and removing files and folders
# *   Scripts

# %% [markdown]
# ###Course server
#
# * The course server is called `vm0964.kaj.pouta.csc.fi`
#   * Connecting needs a program, such as PuTTY
#   * PuTTY can be installed freely to any Windows laptop (https://www.chiark.greenend.org.uk/~sgtatham/putty/latest.html)
# * On Linux / Mac machines, you have a Terminal from which you can `ssh` to the server with `ssh USERNAME@vm.9064.kaj.pouta.csc.fi`
#
# * Your username is your UTU username
# * Your password is told at class and illustrated on Moodle

# %% [markdown]
# ### Change your password
# * The command is `passwd`
# * Note that **you can't see the password** when typing

# %% [markdown]
# ### Browsing text files
# * `cat`, `head`, `tail` work
# * `less` useful to browse a file (`q` takes you away from less)
# * `less` useful at the end of pipes
#
#     `cat file.txt | egrep "cool" | less`

# %% [markdown]
# ## File system
#
# * **Folders and subfolders** similarly to any (Windows or other) machine
# * Each user has their own **home directory** (and possible subdirectories)
# * Here's a nice figure: http://unix.stackexchange.com/questions/89114/what-does-the-jargon-filesystem-mean
#
# *  **Paths** (the *route* from folder A to folder B, or the *location* of folder C/file D) are essential
#
#   `folder/subfolder/subsubfolder`
#
#   `home/folder/subfolder/file.txt`
#
# * `pwd` prints the whole path of the folder
#
# * `cd` for moving between directories
#   * Upwards:` cd ..` Note the **space**!
#   * Downwards: `cd folder`
#   * Upwards and then downwards: `cd ../anotherfolder`
# * Back to home directory: `cd ~`
# ---------
# ###Creating folders and files
#
# **Folders**
#
# Create a folder:
#
# `mkdir myfolder`
#
#
# **Files**
#
# To create a file, you need to use a **text editor** such as emacs or nano. To create a file, you simply type
#
# `emacs myfile.txt`
#
# or
#
# `nano myfile.txt`
#
# These commands (create and) open a file you can edit.
#
# **N.B. 1 Saving and exiting the text editors**
#
# **emacs**
#
# to **exit** emacs, press control+x control+c
#
#   to **save** press control+s control+c
#
# **nano**
#
# In nano you find these commands inside the editor. `^` stands for ctrl
#
#
#
# **N.B. 2 File and folder names**
#
# When naming the files (or directories/folders), do **not** use spaces or full stops (e.g., `my.file.txt` or `my file.txt` will not work). Instead, use underscore (`my_file.txt`), hyphen (`my-file.txt`) or camel case (`myFile.txt`) or write everything as one word (`myfile.txt`). This is good practice and will prevent many problems.
#
# ---------
# ### Copying, moving and removing files
# **Copying**
# * Downwards:
#
#   `cp file.txt folder/`
# * Upwards:
#
#   ` cp file.txt ../`
# * In this context, the single dot (.) in the end means the working directory (the one you're in at the moment):
#
#   `cp ../file.txt .`
#
#   The command above can be read as "copy from the folder above (`../`) `file.txt` to this location/folder where I am now".
#
# * Copy to a new file (cf. save as); results in two files (the original and its copy):
#
#   ` cp file.txt file1.txt`
#
# * Copying to a new file and moving the copy:
#
#   `cp file.txt folder/file1.txt`
#
# **Moving**
# * Downwards:
#
#  `mv file.txt folder/`
# * Upwards:
#
#   ` mv file.txt ../`
#
# * Renaming; results in one file (the original which is moved):
#
#   ` mv file.txt file1.txt`
#
# * Renaming and moving:
#
#   ` mv file.txt ../file1.txt`
#
#
# **Removing**
#
# `rm file.txt`
#
# remove a file
#
# `rmdir folder`
#
# remove a folder; NB! will only reove the folder if it is empty
#
# **!!!** **NO** questions "are you sure you want to delete the file/folder?" asked **!!!**

# %% [markdown]
# ### **Time out 1**
#
# 1. Make sure you can log in to the server.
#
# 2. Try out working on the server. Useful commands can be `mkdir, rmdir, cp, mv, rm` (rmdir and rm go for remove, so remember to be careful! There's no checking whether you really want to remove the file/folder!)
#
#   a) Create a directory called `My_directory` to your home folder
#
#   b) Create a file called `myfile.txt` to the folder. Try to write something to it using a text editor.
#
#   c) Take a copy of `myfile.txt` and rename it as `backup-of-myfile.txt`
#
#   d) Take a file from Gutenberg (https://gutenberg.org/) and browse it with different methods: `head, tail, cat, less`. Note the differences!
#
#   ... And note that **text editors are not great for browsing larger files**, so avoid that!
#
#   e) Finally, remove all files and directories you created during this exercise. You can check with `ls` if you succeeded!

# %% [markdown]
# ## Scripts
#
# * Long command combinations can become complicated.
# * The commands can be saved in a script that can then be executed instead of typing the individual commands on command line
# *   Scripts are useful in that they save the commands also for later use
#
#
# ----
#
# ###  Script file
#
# * Bash scripts should have the ending
#
#   `.sh`
# * Bash scripts should start with
#
#   ` #!/bin/bash`
# * They can be executed by
#
#   `./script.sh` (or `sh script.sh` or `bash script.sh`)
# * **Important**: you need to add **executing permissions** to your script.
#
#   `chmod a+x script.sh`
#
# ### Script input and output
#
# * **Standard input / output**
#
#   `cat input.txt | ./script.sh`
#
#   `cat input.txt | ./script.sh > output.txt`
#
#   first print the file, then the script **in pipe** and finally direct the output to a new file
#
#   The script file itself may look like this
#
#      ```
#   #!/bin/bash
#   egrep "cat" | wc -l
# ```
#
#   or like this (each pipe on a separate row)
#
#   ```
#   #!/bin/bash
#   egrep "cat" |
#     wc -l
# ```
#   **N.B.** The script can feature comments
#   ```
#   #!/bin/bash
#   egrep "cat" | #here you can write comments
#     wc -l #the hashtag marks them as comments and not executable code
# ```
#
#   When the script is executed, the commands in the script file are run on the data file, as in a corresponding command
#
#   `cat input.txt | egrep "cat" | wc -l`
#
#
# * **Arguments**
#
#   `./script.sh input.txt`
#
#   `./script.sh input.txt > output.txt`
#
#   When using arguments, the execute command `./script.sh` is typed first and then the arguments (in this case the file `input.txt`). **No pipes** are used.
#
#   Arguments (such as `input.txt` above) are referred to with` $1
#   `, `$2`, etc in the script (inside the script file)
#
#   Say we have a script counting the lines in the file `script.sh` that looks like this:
#   ```
#   #!/bin/bash
#   $1 | wc -l
# ```
#
#   The `$1` refers to the first argument given with the execute command (our data file `input.txt`).
#
#   Then we run the script with the execute command and provide our data file `input.txt` as an argument to it (i.e. in this case the file the script should be run on):
#
#   `./script.sh input.txt`
#
#   When running the script, Bash understands that `$1` refers to the first argument in the execute command, i.e. our data file `input.txt`, and reads it in in the correct place, as in a corresponding command
#
#   `input.txt | wc -l`
#
#   There can be several arguments, and these get running numbering (`$1`, `$2`, `$3` and so on in the script).
#
#   E.g. if we have a script that greps different tokens `script_tokens.sh`, we could give the token to be grepped (e.g. `"cat"`) as the second argument:
#
#   `./script_tokens.sh input.txt "cat"`
#
#   In the script file `script_tokens.sh` the script could look as follows:
#   ```
#   #!/bin/bash
#   $1 |
#     egrep $2
# ```
#
#   and Bash would know to read the `input.txt` file as the first argument and `"cat"` as the second argument, as in a corresponding command
#
#   `input.txt | egrep "cat"`
#
# **In sum**
#
#
#
# *   **Standard input/output** reminds more of the usual commands we've worked with as commands are written in **pipes** and it takes **no arguments**
# *   Using **arguments** might seem a bit more tedious with the `$`within the script and the arguments when executing it. However, using arguments gives more flexibility if you have (several) variables you want to change in the script. Remember, though, that there are **no pipes** when running `.sh` scripts with arguments.
#
#
#
# *   All in all, scripts are useful in that you can **use the same command multiple times on several files** without having to type the (long) command over and over again. By using scripts you also **minimize the risk for typos and errors** which you face more easily when typing a command several times.

# %% [markdown]
# ### **Timeout 2.1**
#
# First make a script that counts **how many words** a file has
#   * For data, you can fetch any file from the folder `/home/mavela/data-2022`
#   * Remember that with `ls` `/home/mavela/data-2022` you can list the contents of the folder so you can decide which one to fetch
#
# * The script should take the file from **standard input (pipe)**
# * Many of the files are quite messy. You can first make a script that counts all the words of the file, and then refine it to count only actual text in the file
#
# ### **Timeout 2.2**
# * **Advanced**: make a script that downloads a Gutenberg book and prints a clean frequency list (to standard output or to a file)
# * Note that wget -O allows you to name the downloaded file as you like

# %%
! wget -O "MYFILE.txt" https://www.gutenberg.org/files/84/84-0.txt
