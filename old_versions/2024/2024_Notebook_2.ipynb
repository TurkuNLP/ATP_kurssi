# %% [markdown]
# <a href="https://colab.research.google.com/github/TurkuNLP/ATP_kurssi/blob/master/2024_Notebook_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Notebook 2: more commands, flags (options) and pipes
#
# ## egrep (or grep)
# * Matches a pattern on a line and prints the line with the match (N.B. A line ends in a line break, so the lines might be long.)
# * see http://people.uta.fi/~jm58660/jutut/unix/grep.html
# * e.g. `egrep "is" filename`
# * Note that capitals and whitespaces count!
# * So `egrep " is" fileame` gives a different output

# %%
# let's first get the data we had previously
! wget https://www.gutenberg.org/cache/epub/20748/pg20748.txt
! ls
# Out:
# --2024-11-01 10:01:59--  https://www.gutenberg.org/cache/epub/20748/pg20748.txt
# Resolving www.gutenberg.org (www.gutenberg.org)... 152.19.134.47, 2610:28:3090:3000:0:bad:cafe:47
# Connecting to www.gutenberg.org (www.gutenberg.org)|152.19.134.47|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 238904 (233K) [text/plain]
# Saving to: ‘pg20748.txt’
#
# pg20748.txt         100%[===================>] 233.30K  --.-KB/s    in 0.1s
#
# 2024-11-01 10:02:00 (1.84 MB/s) - ‘pg20748.txt’ saved [238904/238904]
#
# pg20748.txt  sample_data

# %%
! mv pg20748.txt book.txt # let's change the name to an easier one

# %%
! head book.txt # let's have a look to remins us what's inside
# Out:
# ﻿The Project Gutenberg eBook of Favorite Fairy Tales
#
# This ebook is for the use of anyone anywhere in the United States and
# most other parts of the world at no cost and with almost no restrictions
# whatsoever. You may copy it, give it away or re-use it under the terms
# of the Project Gutenberg License included with this ebook or online
# at www.gutenberg.org. If you are not located in the United States,
# you will have to check the laws of the country where you are located
# before using this eBook.

# %%
! egrep "snow" book.txt
# Out:
# Once upon a time in the middle of winter, when the flakes of snow were
# she was thus engaged and looking out at the snow she pricked her finger,
# and three drops of blood fell upon the snow. Now the red looked so well
# white as this snow, as red as this blood, and as black as the wood of
# white as snow, and with cheeks as red as blood, and with hair as black
# with snow-white sheets.
# exclaimed, "White as snow, red as blood, black as ebony! This time
# but looked as if she were only asleep, for she was still white as snow,
# with hail or snow, and the Raven sat on the hedge and croaked. The poor
# among the bushes into the new-fallen snow, and there he lay as in a
# to suffer from the frost, and snow and storms of the winter. He was
# It was dreadfully cold, it was snowing fast, and almost dark; the
# The snowflakes fell on her long fair hair, which curled in such pretty
# with straw and rags, the wind and snow often came through.
# ...

# %%
! egrep "Snow" book.txt
# Out:
# as ebony, and from this she was named "Snow-White." And at the same time
# Little Snow-White, however, grew up, and became prettier and prettier,
#      Snow-White is the fairest, now, they say."
# From that hour, whenever she saw Snow-White, her heart was hardened
# But now poor little Snow-White was left motherless and alone, and
# Little Snow-White, being both hungry and thirsty, ate a little morsel of
# saw Snow-White sleeping in it; so he called his companions, who shouted
# As soon as morning dawned Snow-White awoke, and was quite frightened
# "My name is Snow-White," was her reply.
# And Snow-White answered, "Yes, with all my heart and will." And so she
#      Snow-White is fairest now, they say.
# Snow-White was still alive. So she dyed her face and clothed herself as
# Snow-White peeped out of the window and said, "Good day, my good woman;
# "I may let in this honest woman," thought Snow-White; and she unbolted
# ...

# %%
! egrep "Snow " book.txt

# %% [markdown]
# ## More about flags / options
#
# * Options are arguments that can be given to Unix commands to change their behavior. These form one of the core elements of Unix command line work.
#
# * most flags have both a short from (e.g. `-v`) and a long form (e.g. `--verbose`); we use short forms whenever possible since it's faster to write
#
# * Options are difficult to remember but you can read them for instance on man pages or google for instrutions (which are probably easier to understand than man pages)

# %%
# an example of the manual page for ls
! man ls
# Out:
# This system has been minimized by removing packages and content that are
# not required on a system that users do not log into.
#
# To restore this content, including manpages, you can run the 'unminimize'
# command. You will still need to ensure the 'man-db' package is installed.

# %%
# In Colab the man pages have been 'minimized', so you need to run this first
# before Colab will show them to you:
! unminimize
# Colab will ask you if you really want to do this;
# click on the area behind the question, type 'y' and press enter.
# After running this cell you can try the cell above again.
# Out:
# This system has been minimized by removing packages and content that are
# not required on a system that users do not log into.
#
# This script restores content and packages that are found on a default
# Ubuntu server system in order to make this system more suitable for
# interactive use.
#
# Reinstallation of packages may fail due to changes to the system
# configuration, the presence of third-party packages, or for other
# reasons.
#
# This operation may take some time.
#
# Would you like to continue? [y/N] ^C

# %% [markdown]
# ### Some useful options
#
# * `head -n 15` prints 15 first lines
# * `tail -n 15` prints 15 last lines
# * `wc -w` prints wordcount
# * `wc -l` prints linecount

# %%
# let's try a bit!
! head -5 book.txt
! echo "-----"
! wc -l book.txt
! wc -w book.txt
# Out:
# ﻿The Project Gutenberg eBook of Favorite Fairy Tales
#
# This ebook is for the use of anyone anywhere in the United States and
# most other parts of the world at no cost and with almost no restrictions
# whatsoever. You may copy it, give it away or re-use it under the terms
# -----
# 5070 book.txt
# 42988 book.txt

# %% [markdown]
# * `egrep -v` (reverse) prints lines without a match
# * `egrep -c` counts matches
# * `egrep -i` ignores case
# * `egrep -w` matches just words
# * `egrep -B N` prints N lines Before
# * `egrep -A N` prints N lines After

# %%
! egrep -i "snow" book.txt
! egrep -w "snow" book.txt
! egrep -wi "snow" book.txt # the flags can also be combined
! egrep -v "snow" book.txt
# Out:
# Striimattava tuloste lyhennetty viimeiseen 5000 riviin.
#
# _ONE HUNDRED ILLUSTRATIONS_
#
# THE JOHN C. WINSTON COMPANY
# CHICAGO  PHILADELPHIA  TORONTO
#
#
#
#
# COPYRIGHT, 1917, BY
# L. T. MYERS
# PRINTED IN U. S. A.
#
#
#
#
# CONTENTS
#
#                                    PAGE
#
# LITTLE SNOW WHITE                     5
#
# THE UGLY DUCKLING                    22
#
# ALADDIN AND THE WONDERFUL LAMP       43
#
# THE SLEEPING BEAUTY                  64
#
# PUSS-IN-BOOTS                        73
#
# ADVENTURES OF TOM THUMB              81
#
# THE THREE BEARS                      95
#
# THE LITTLE MATCH GIRL               103
#
# BEAUTY AND THE BEAST                109
#
# THE STORY OF CINDERELLA             122
#
# JACK THE GIANT KILLER               135
#
# JACK AND THE BEANSTALK              155
#
# DICK WHITTINGTON AND HIS CAT        167
#
# THE STORY OF BLUEBEARD              184
#
# LITTLE RED RIDING-HOOD              195
#
# SINDBAD THE SAILOR                  202
#
# ...

# %%
! egrep -c "snow" book.txt
! egrep -c "Snow" book.txt
! egrep -ic "snow" book.txt
! egrep -icw "snow" book.txt
# Out:
# 17
# 32
# 51
# 49

# %%
! egrep -B 5 -A 5 "Snow" book.txt
# Out:
# and three drops of blood fell upon the snow. Now the red looked so well
# upon the white that she thought to herself, "Oh, that I had a child as
# white as this snow, as red as this blood, and as black as the wood of
# this frame!" Soon afterwards a little daughter came to her, who was as
# white as snow, and with cheeks as red as blood, and with hair as black
# as ebony, and from this she was named "Snow-White." And at the same time
# her mother died.
#
# About a year afterwards the King married another wife, who was very
# beautiful, but so proud and haughty that she could not bear anyone to be
# better-looking than herself. She owned a wonderful mirror, and when she
# --
#
#     "The Queen is the fairest of the day."
#
# Then she was pleased, for she knew that the mirror spoke truly.
#
# Little Snow-White, however, grew up, and became prettier and prettier,
# and when she was seven years old she was as fair as the noonday, and
# ...

# %% [markdown]
# ### Time to try things out!
#
# 1. How to rename a file?
# 2. How to count how many words and lines a file has?
# 3. How to count how many times the pronoun _he_ appears in a file? How can you control the use of capitals and white spaces so that the query matches only entire words?
# 4. How to direct the number of lines that match the query (_he_) to a file?
# For instance, the file could include the following lines:
#
# ```
# He appeared this many times:
# 15
# ```
# ### Advanced
# * You can also combine commands on one line using ;
# * You can assign variables using $:

# %%
! wordcount=$(wc -w book.txt) ; echo "Word count is $wordcount"
# Out:
# Word count is 42988 book.txt

# %%
! wordcount=$(wc -w book.txt) ; echo "Word count is $wordcount"
! echo "Word count is", $wordcount # this won't work anymore on Colab, because each line is interpreted individually
# Out:
# Word count is 42988 book.txt
# Word count is,

# %% [markdown]
# ### Pipes (*putket* in Finnish)
#
# * You can combine commands with a pipe | (alt gr + the key next to z)
# * This way the output of the first command goes as input to the next one
# * `cat file.txt | wc -w` (is actually the same as just `wc -w`) first prints a file, then counts words
# * `cat file.txt | egrep "is"`  first prints a file, then matches the pattern
# * `cat file.txt | egrep "is"  | wc -l`
# * `cat file.txt | egrep "is" | head`
# * `cat file.txt | egrep "is" > output.txt`
# * `cat file.txt | head -1000 | tail -100`  prints the lines between 900-1000

# %%
! cat book.txt | egrep "is" | wc -l
! cat book.txt | egrep "is" | head
# Out:
# 1058
# This ebook is for the use of anyone anywhere in the United States and
# of the Project Gutenberg License included with this ebook or online
# before using this eBook.
# Language: English
#         Online Distributed Proofreading Team at https://www.pgdp.net
# Online Distributed Proofreading Team at https://www.pgdp.net
# white as this snow, as red as this blood, and as black as the wood of
# this frame!" Soon afterwards a little daughter came to her, who was as
# as ebony, and from this she was named "Snow-White." And at the same time
#      Who is the fairest of us all?"

# %%
! cat book.txt | egrep -w "is" | wc -l
! cat book.txt | egrep -w "is" | head
# Out:
# 137
# This ebook is for the use of anyone anywhere in the United States and
#      Who is the fairest of us all?"
#     "The Queen is the fairest of the day."
#      Who is the fairest of us all?"
#      Snow-White is the fairest, now, they say."
# "Oh, heavens! oh, heavens!" said they; "what a beauty she is!" and they
# "My name is Snow-White," was her reply.
#      Who is the fairest of us all?"
#      Snow-White is fairest now, they say.
#      Who is the fairest of us all?"

# %%
! cat book.txt | egrep -wi "is" | head
! cat book.txt | egrep -wi "is" | wc -l
# Out:
# This ebook is for the use of anyone anywhere in the United States and
#      Who is the fairest of us all?"
#     "The Queen is the fairest of the day."
#      Who is the fairest of us all?"
#      Snow-White is the fairest, now, they say."
# "Oh, heavens! oh, heavens!" said they; "what a beauty she is!" and they
# "My name is Snow-White," was her reply.
#      Who is the fairest of us all?"
#      Snow-White is fairest now, they say.
#      Who is the fairest of us all?"
# 140

# %%
# Again, you can direct these to a file as before
! cat book.txt | egrep -wi "is" | wc -l > file.txt
! cat file.txt
# Out:
# 140

# %% [markdown]
# ## Frequency counts
#
# * A frequency counter can be done by combining *sort* and *uniq* commands with a pipe
# * `sort` sorts the input lines to alphabetical order
# * `uniq` filters repetitive lines

# %%
# this gives us a new dataset
! wget http://dl.turkunlp.org/atp/tweets_en_nort.csv
# Out:
# --2024-11-01 10:39:32--  http://dl.turkunlp.org/atp/tweets_en_nort.csv
# Resolving dl.turkunlp.org (dl.turkunlp.org)... 195.148.30.23
# Connecting to dl.turkunlp.org (dl.turkunlp.org)|195.148.30.23|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 82188071 (78M) [application/octet-stream]
# Saving to: ‘tweets_en_nort.csv’
#
# tweets_en_nort.csv  100%[===================>]  78.38M  22.9MB/s    in 4.4s
#
# 2024-11-01 10:39:37 (18.0 MB/s) - ‘tweets_en_nort.csv’ saved [82188071/82188071]

# %%
# What does the data look like?

! head tweets_en_nort.csv

#! cat tweets_en_nort.csv | head #outputs the same thing as the command above
# Out:
# 15	twitter-search	@_Tsunamilkshake pas top #CharlieHebdo #JeSuisCharlie	2537743877	theo_yagami	552895821730316288	1215660151	en	<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>	http://pbs.twimg.com/profile_background_images/881023503/57d97605059e6a7d321b75c46ac2323a.jpeg		0	0	Wed Jan 07 18:33:30 +0000 2015	1420655610
#
# 17	twitter-search	NA		hojaldraoficial	552895821600264192	763672748	en	<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>	http://abs.twimg.com/images/themes/theme1/bg.png		0	0	Wed Jan 07 18:33:30 +0000 2015	1420655610
#
# 103	twitter-search	Je suis Charline, mais surtout #JeSuisCharlie- freedom of speach is a right! http://t.co/5KLOA114C9		CharlineDeLucaC	552895817003323392	834937038	en	<a href="http://instagram.com" rel="nofollow">Instagram</a>	http://pbs.twimg.com/profile_background_images/690731646/217479ce77b3fa1a6f904db60cc48b9c.jpeg		0	0	Wed Jan 07 18:33:29 +0000 2015	1420655609
#
# ...

# %% [markdown]
# This data has several columns.
# Let's first take just the tweet parts from the data, it's the column number 3.
#
# We can get a specific column with `cut`.
# Using `cut -f 3` will give us column 3.
#
# Also, there seem to be empty lines. Those we can delete with `egrep -v "^$"`

# %%
! cat tweets_en_nort.csv | egrep -v "^$" | cut -f 3 | head -20
# Out:
# @_Tsunamilkshake pas top #CharlieHebdo #JeSuisCharlie
# NA
# Je suis Charline, mais surtout #JeSuisCharlie- freedom of speach is a right! http://t.co/5KLOA114C9
# The depraved ways of Islamic extremism should never be allowed to force people into silence. #JeSuisCharlie http://t.co/IZqNiFKBeM
# Incredibly sad news out of France today. My thoughts go out to the family and friends of the staff at @Charlie_Hebdo_ #JeSuisCharlie
# No country is free if its press cannot practice openly and fearlessly. #JeSuisCharlie http://t.co/YCXeKDyJEp
# Being in Paris, absolutely shocked at the #CharlieHebdo #terrorism attack. Condolences. #FreeSpeech #Secular #JeSuisCharlie
# My wife wrote this: http://t.co/Y0HlA2qCCp #JeSuisCharlie
# German public anti Islamic feelings are now strengthened by the attack in Paris #JeSuisCharlie
# NetNewsLedger #JeSuisCharlie Hashtag Goes Viral Condemning Paris Terror Attack: PARIS - NEWS - People from aro... http://t.co/ACNdobn17V
# ...

# %%
# let's direct this to a file that we can then use
! cat tweets_en_nort.csv | egrep -v "^$" |  cut -f 3 > tweets_text.txt

# %%
! cat tweets_text.txt | head
# Out:
# @_Tsunamilkshake pas top #CharlieHebdo #JeSuisCharlie
# NA
# Je suis Charline, mais surtout #JeSuisCharlie- freedom of speach is a right! http://t.co/5KLOA114C9
# The depraved ways of Islamic extremism should never be allowed to force people into silence. #JeSuisCharlie http://t.co/IZqNiFKBeM
# Incredibly sad news out of France today. My thoughts go out to the family and friends of the staff at @Charlie_Hebdo_ #JeSuisCharlie
# No country is free if its press cannot practice openly and fearlessly. #JeSuisCharlie http://t.co/YCXeKDyJEp
# Being in Paris, absolutely shocked at the #CharlieHebdo #terrorism attack. Condolences. #FreeSpeech #Secular #JeSuisCharlie
# My wife wrote this: http://t.co/Y0HlA2qCCp #JeSuisCharlie
# German public anti Islamic feelings are now strengthened by the attack in Paris #JeSuisCharlie
# NetNewsLedger #JeSuisCharlie Hashtag Goes Viral Condemning Paris Terror Attack: PARIS - NEWS - People from aro... http://t.co/ACNdobn17V

# %% [markdown]
# Then to the **frequency counter** part
#
# *   `sort` sorts the lines **alphabetically**

# %%
! cat tweets_text.txt | sort | head # the beginning of the sorted document looks like this
# Out:
# $100 to tfirst @ColumbiaLaw student in #AmalClooney's lecture who posts a video/audio of one lecture. #JeSuisCharlie indeed. #GeorgeClooney
# $10k Muhammad Art &amp; Cartoon Contest 2B Held @ Site of 'Stand W/ the Prophet'... http://t.co/DafEa4HnVd #JeSuisCharlie #freespeech #tcot
# $10m gift to help house the neediest http://t.co/t8mKnBkETh #JeSuisCharlie
# $1K #REWARD http://t.co/i6KZlINOta http://t.co/8OJgTXywuM If people cant stand #JeSuisCharlie terrorism, how can we stand THIS terroris.
# $1K #REWARD http://t.co/ZW8gvbP2gC http://t.co/Sgh6TuSRa0 If people cant stand #JeSuisCharlie terrorism, how can we stand THIS terrorism?
# $600 USD for #CharlieHebdo magazine and 8 sold already on EBAY http://t.co/JJC1QSJv3U #JeSuisCharlie #Ebay
# $EBAY:US #JeSuisCharlie creator seeks copyright to protect slogan #EBAY INC http://t.co/2laU0xN6Qz #SP500
# $EBAY:US #JeSuisCharlie creator seeks copyright to protect slogan #EBAY INC http://t.co/6g1Yf0vamg #SP500
# ...

# %%
! cat tweets_text.txt | sort | head -3000 | tail
# Out:
# a good one #jesuischarlie #exmuslim #atheist http://t.co/2SBWrz2REl
# A good read about why we - especially the left - need to support @Charlie_Hebdo_ https://t.co/BTpR3MUGL7 #JesuisCharlie #CharlieHebdo
# A good read as to why O probably didn't go to Paris. @gegco @tcot #JeSuisCharlie #UnityMarch http://t.co/Lsdauk5QDB
# A good read for anyone who for whatever reason thinks relgion wasn't the driving force behind attacks. #JeSuisCharlie http://t.co/vpM1tJzkDW
# A good read: "Muslims and Westerners: The Psychological Differences": http://t.co/VZh6LuStjk #JeSuisCharlie
# A good reason to stop making false equivalences. https://t.co/zJJ3dnNjDr #Garland #JeSuisCharlie
# A good reminder that binaries are problematic. via @vicenews &amp; @natashalennard http://t.co/h9OzzwCu3C #jesuischarlie #jenesuispascharlie
# A good reminder that #FreeSpeech is also violently suppressed by western governments...: http://t.co/K8P3Zah6XD by @tejucole #JeSuisCharlie
# ...

# %% [markdown]
# * `uniq` prints only unique lines, i.e., deletes duplicate lines that follow each other
# * `uniq -c` only counts the number of duplicate lines
#
#   --> important to sort the lines first

# %%
! cat tweets_text.txt | sort | uniq -c | head # alway use sort before uniq!
# Out:
#       1 $100 to tfirst @ColumbiaLaw student in #AmalClooney's lecture who posts a video/audio of one lecture. #JeSuisCharlie indeed. #GeorgeClooney
#       1 $10k Muhammad Art &amp; Cartoon Contest 2B Held @ Site of 'Stand W/ the Prophet'... http://t.co/DafEa4HnVd #JeSuisCharlie #freespeech #tcot
#       1 $10m gift to help house the neediest http://t.co/t8mKnBkETh #JeSuisCharlie
#       1 $1K #REWARD http://t.co/i6KZlINOta http://t.co/8OJgTXywuM If people cant stand #JeSuisCharlie terrorism, how can we stand THIS terroris.
#       1 $1K #REWARD http://t.co/ZW8gvbP2gC http://t.co/Sgh6TuSRa0 If people cant stand #JeSuisCharlie terrorism, how can we stand THIS terrorism?
#       1 $600 USD for #CharlieHebdo magazine and 8 sold already on EBAY http://t.co/JJC1QSJv3U #JeSuisCharlie #Ebay
#       1 $EBAY:US #JeSuisCharlie creator seeks copyright to protect slogan #EBAY INC http://t.co/2laU0xN6Qz #SP500
# ...

# %% [markdown]
# Using `sort -n` again sorts the lines **by their number**

# %%
! cat tweets_text.txt | sort | uniq -c | sort -n  # This command pipe may take a while to print out! How would you fix that?
# Out:
# Striimattava tuloste lyhennetty viimeiseen 5000 riviin.
#       1 Where are all the women? Male leaders photoshopped out of Paris march. #JeSuisCharlie http://t.co/Cf5naaYmFV via @SarahElzeini #EqualityFail
#       1 Where are all the #worldleaders? Why haven't they marched like they did for #JeSuisCharlie? #CharlestonShooting @POTUS
#       1 Where are all this people who tweeted #JeSuisCharlie ? Was that the only terrorist atack that mattered ? #IamMuath
#       1 Where are all those #JeSuisCharlie now that Kenya needs global support to condemn hate and violence? #KenyaAttack
#       1 where are all those #jesuischarlie people right now? #chapelhillshooting
#       1 Where are all those people down the streets to defend freedom when they were #CharlieHebdo ? Si #JeSuisCharlie #JeSuisKenyan #IAmKenya
#       1 Where are all those who wrote #JeSuisCharlie? Why isn't anyone writing #IamMuath?
# ...

# %% [markdown]
# `sort -nr` sorts the lines by their number **in reverse order** --> perhaps a bit more practical

# %%
! cat tweets_text.txt | sort | uniq -c | sort -nr | head
# Out:
#   17347 NA
#     314 Zoolou M. Couillard Fill... it Up and Keep the Change Un bon cultivateur arrache les mauvais #polqc #JeSuisCharlie http://t.co/zBP6TwwqDp
#     314 Serpent Couillard Fill... it Up and Keep the Change Un bon cultivateur arrache les mauvaises hr #polqc #JeSuisCharlie http://t.co/zBP6TwwqDp
#     222 Islamophobia? Fear of Islam NOT irrational. Plenty evidence to support rational fear. #JeSuisJuif #JeSuisCharlie http://t.co/B1n0HBodgV
#     207 #Racism in #France #jesuischarlie | don't forget &amp; don''t ignore racism against&gt;#Roma #Sinti |http://t.co/mUdugQxref &amp;http://t.co/5yoVEzat9Z
#     186 #JeSuisCharlie South Korea is not a democratic country. http://t.co/H7H9QtJPr9 #BentonCity #Bingen
#     180 #JeSuisCharlie #SouthKorea is not a democratic country. http://t.co/u1eapam9uq #Brier #Buckley #Burien
#     149 #JeSuisCharlie #SouthKorea is not a democratic country. http://t.co/u1eapam9uq #Brewster #Bridgeport
# ...

# %% [markdown]
# ### ... so this is how we finally have the frequencies!

# %% [markdown]
# ### What did we learn?
#
# * Flags are used to change or specify commands
# * Pipes are used to combine commands
# * New flags and commands
#   * `egrep` match character strings
#   * `egrep` + flags
#   * `egrep -v "^$"` delete empty lines
#   * `cut -f` select a specific column
#   * `sort`
#   * `uniq`
#   * `sort | uniq -c | sort -rn` frequency list
